# %% [markdown]
# 目標: 使用 Seaborn 自帶的dataset, 利用 PANDAS 處理來繪製資料集的可是畫圖表
#
# 重點: 不同型態的類別要套用的對應圖像是不一樣的
#
# 作業: 取得另一個 dataset: titanic, tips
#
# (1) 做條形圖
#
# (2) 異常值落點分析

# %%
# 導入必要的程式庫
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# 取得資料集
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# 選取特徵值: sex, survived, 主要是這個資料集用來做存活率做預測, 所以Y label 一定是用survived
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
# 直接使用PANDAS dataframe, 當作參數
# 條形圖()顯示分類變數和連續變數之間的關係。數據以矩形條表示,其中條的長度表示該類別中數據的比例。
# x, y 表示特徵值, data 給定dataframe 
sns.barplot(x = "sex", y = "survived", hue = "class", data = df)
plt.show()

# %% [markdown]
# 在上面的示例中,我們可以看到每個班級中男性和女性的平均存活率。從情節中,我們可以理解,女性存活人數比男性多。在男性和女性中,更多的存活率來自頭等艙。
#
# barplot 中的特殊情況是顯示每個類別中的觀測值的"否",而不是計算第二個變數的統計資訊。

# %% [markdown]
# 使用範例的圖形檢視另一個資料集

# %%
# 某些情況下, 會需要把兩種類型的圖混合
# 在箱型圖上繪製分類散點圖, 可以更容易理解異常值的分布
# 導入必要的程式庫
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# 取得資料集
df2= sns.load_dataset('tips')
# 利用df.info 檢查有哪些特徵值
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
# 先行挑選兩組特徵: 
sns.boxplot(x='smoker',y='total_bill',data=df2)
sns.stripplot(x='smoker', y='total_bill', data=df2, jitter=0.1)
plt.show()

# %%
# 直接使用PANDAS dataframe, 當作參數
# 條形圖()顯示分類變數和連續變數之間的關係。數據以矩形條表示,其中條的長度表示該類別中數據的比例。
# x, y 表示特徵值, data 給定dataframe 
'''
df=pd.DataFrame({
       'sex': df['sex'],
       'class': df['class'],
       'values': df['survived']})
'''
df.to_csv('df.csv')
df=pd.read_csv('df.csv',usecols=['survived','sex','class'])
df=df.pivot_table(values='survived',index=['sex','class'],aggfunc=np.mean)
print(df)

#ax=sns.barplot(y=index,data=df,orient='h')
# Out:
#                survived
# sex    class
# female First   0.968085
#        Second  0.921053
#        Third   0.500000
# male   First   0.368852
#        Second  0.157407
#        Third   0.135447

# %%
df2 = pd.DataFrame({'k1': [1, 2, 3], 'k2': [1, 2, 3], 'v': [4, 5, 6]})
df2.pivot_table(values='v', columns=('k1','k2'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-5f9477ebe1a8> in <module>
#       1 df2 = pd.DataFrame({'k1': [1, 2, 3], 'k2': [1, 2, 3], 'v': [4, 5, 6]})
# ----> 2 df2.pivot_table(values='v', columns=('k1','k2'))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6068         from pandas.core.reshape.pivot import pivot_table
#    6069
# -> 6070         return pivot_table(
#    6071             self,
#    6072             values=values,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     173         and not values_multi
#     174         and not table.empty
# ...
